# %% [markdown]
# <a href="https://colab.research.google.com/github/madesh948377-commits/Dav-Lab/blob/main/2026lcs029_exp_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#---Numpy array operation---
arr=np.array([10,20,30,40,50])
print ('Array :',arr)

# %%
print('Mean:',arr.mean())
