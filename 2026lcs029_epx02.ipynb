# %% [markdown]
# <a href="https://colab.research.google.com/github/madesh948377-commits/Dav-Lab/blob/main/2026lcs029_epx02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import numpy as np

# %%
data = {
    'Name':['Amit','Beho','chetan','Amit','Dvya','Ravi','Shena','karan','pooja','Manish','anjali','suresh','kavya','rahaul','merra','vikram','nisha','arjun','divya','rohith','swathi','navven','priya','karan','deepa'],
    'Age':[25,22,30,25,28,22,24,23,27,26,23,29,22,25,22,28,24,22,28,26,23,30,27,23,25],
    'Marks': [85,85,90,85,78,95,88,72,85,91,67,84,79,95,93,88,76,82,78,96,90,85,71,72,89],
    'city' : ['Mysuru','bengaluru','Dehli','mysuru','bengaluru','Mysuru','Mysuru','Mysuru','Mysuru','Mysuru','bengaluru','dehli','mysuru','bengaluru','dehli','bengaluru','bengaluru','bengaluru','bengaluru','bengaluru','bengaluru','bengaluru','bengaluru','bengaluru'
    ,'bengaluru']
}
df = pd.DataFrame(data)
print("Dataset:")
print(df)
# Out:
# Dataset:
#       Name  Age  Marks       city
# 0     Amit   25     85     Mysuru
# 1     Beho   22     85  bengaluru
# 2   chetan   30     90      Dehli
# 3     Amit   25     85     mysuru
# 4     Dvya   28     78  bengaluru
# 5     Ravi   22     95     Mysuru
# 6    Shena   24     88     Mysuru
# 7    karan   23     72     Mysuru
# 8    pooja   27     85     Mysuru
# 9   Manish   26     91     Mysuru
# 10  anjali   23     67  bengaluru
# 11  suresh   29     84      dehli
# 12   kavya   22     79     mysuru
# 13  rahaul   25     95  bengaluru
# 14   merra   22     93      dehli
# 15  vikram   28     88  bengaluru
# 16   nisha   24     76  bengaluru
# 17   arjun   22     82  bengaluru
# 18   divya   28     78  bengaluru
# 19  rohith   26     96  bengaluru
# 20  swathi   23     90  bengaluru
# 21  navven   30     85  bengaluru
# 22   priya   27     71  bengaluru
# 23   karan   23     72  bengaluru
# 24   deepa   25     89  bengaluru

# %%
print("\nshape of dataset(row,columns):",df.shape)
# Out:
# shape of dataset(row,columns): (25, 4)

# %%
print("/nColumn names:", df.columns.tolist())
# Out:
# /nColumn names: ['Name', 'Age', 'Marks', 'city']

# %%
print("/nData types of each coloums")
print(df.dtypes)
# Out:
# /nData types of each coloums
# Name     object
# Age       int64
# Marks     int64
# city     object
# dtype: object

# %%
print("/nDataset info:")
df.info()
# Out:
# /nDataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    25 non-null     object
#  1   Age     25 non-null     int64
#  2   Marks   25 non-null     int64
#  3   city    25 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 932.0+ bytes

# %%
print("/nDescriptive statics(numerical columns):")
print(df.describe())
# Out:
# /nDescriptive statics(numerical columns):
#              Age      Marks
# count  25.000000  25.000000
# mean   25.160000  83.960000
# std     2.624881   8.064738
# min    22.000000  67.000000
# 25%    23.000000  78.000000
# 50%    25.000000  85.000000
# 75%    27.000000  90.000000
# max    30.000000  96.000000

# %%
print("\nMean:\n", df.mean(numeric_only=True))
# Out:
# Mean:
#  Age      25.16
# Marks    83.96
# dtype: float64

# %%
print("\nMedian:\n", df.median(numeric_only=True))
# Out:
# Median:
#  Age      25.0
# Marks    85.0
# dtype: float64

# %%
print("\nStandard Deviation:\n", df.std(numeric_only=True))
# Out:
# Standard Deviation:
#  Age      2.624881
# Marks    8.064738
# dtype: float64

# %%
print("\nMissing values in each column")
print(df.isnull().sum())
print("\nTotal missing values in dataset:", df.isnull().sum().sum())
# Out:
# Missing values in each column
# Name     0
# Age      0
# Marks    0
# city     0
# dtype: int64
#
# Total missing values in dataset: 0

# %%
print("\nDuplication rows in dataset:")
print(df[df.duplicated()])
print("\nNumber of  duplication rows in dataset:", df.duplicated().sum())
print("\nEDA process complete successfully")
# Out:
# Duplication rows in dataset:
# Empty DataFrame
# Columns: [Name, Age, Marks, city]
# Index: []
#
# Number of  duplication rows in dataset: 0
#
# EDA process complete successfully
